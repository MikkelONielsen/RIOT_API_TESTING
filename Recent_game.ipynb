# %%
print("Hello!")
# Out:
# Hello!

# %%
API_KEY = "RGAPI-a9076744-a527-485a-907b-0fc75c93071a"

# %%
API_KEY
# Out:
# 'RGAPI-a9076744-a527-485a-907b-0fc75c93071a'

# %%
import requests

# %%
def convert_playername_to_url(playername):
    base_url = "https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/"
    api_key = "RGAPI-a9076744-a527-485a-907b-0fc75c93071a"
    url = base_url + playername + "?api_key=" + api_key
def convert_playername_to_url(playername):
    base_url = "https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/"
    api_key = API_KEY
    formatted_playername = playername.replace(" ", "%20")
    url = base_url + formatted_playername + "?api_key=" + api_key
    return url

# %%
playername = "zz TOP KING"

# %%
API_URL = convert_playername_to_url(playername)

# %%
API_URL
# Out:
# 'https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/zz%20TOP%20KING?api_key=RGAPI-a9076744-a527-485a-907b-0fc75c93071a'

# %%
#URL = "https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/zz%20TOP%20KING"

# %%
requests.get(API_URL )
# Out:
# <Response [200]>

# %%
requests.get("https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/summonerName?api_key=RGAPI-a9076744-a527-485a-907b-0fc75c93071a")
# Out:
# <Response [200]>

# %%
API_URL
# Out:
# 'https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/zz%20TOP%20KING?api_key=RGAPI-a9076744-a527-485a-907b-0fc75c93071a'

# %%
response = requests.get(API_URL)
response
# Out:
# <Response [200]>

# %%
player_info = response.json()
player_info
# Out:
# {'id': 'hRJRx3MwMm8u2VmVqIoQ2vNODIlV3roAdw0lk1W2e0eYv08',
#  'accountId': 'NsQeArIgCq9vvilVMe3lMMblCQybEsj7TcjFOantyG8hmA',
#  'puuid': '3nr_4tZu2kCSA0oxbs5RnUzpF-BF-j0SkiQC1A6fgzpg3Rkma5gI5CWo00_sHmMvIpiqlDQnYB5XMw',
#  'name': 'zz TOP KING',
#  'profileIconId': 6570,
#  'revisionDate': 1711415589373,
#  'summonerLevel': 396}

# %%
player_account_id = player_info['puuid']
player_account_id
# Out:
# '3nr_4tZu2kCSA0oxbs5RnUzpF-BF-j0SkiQC1A6fgzpg3Rkma5gI5CWo00_sHmMvIpiqlDQnYB5XMw'

# %%
recent_games_url = f"https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/{player_account_id}/ids?start=0&count=20" + "&api_key=" + API_KEY

# %%
recent_games_url
# Out:
# 'https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/3nr_4tZu2kCSA0oxbs5RnUzpF-BF-j0SkiQC1A6fgzpg3Rkma5gI5CWo00_sHmMvIpiqlDQnYB5XMw/ids?start=0&count=20&api_key=RGAPI-a9076744-a527-485a-907b-0fc75c93071a'

# %%
recent_games_response = requests.get(recent_games_url)

# %%
recent_games_response.json()
# Out:
# ['EUW1_6872214190',
#  'EUW1_6872175419',
#  'EUW1_6872168571',
#  'EUW1_6872117584',
#  'EUW1_6872062333',
#  'EUW1_6872007739',
#  'EUW1_6871962398',
#  'EUW1_6871900515',
#  'EUW1_6871812050',
#  'EUW1_6871726206',
#  'EUW1_6871191443',
#  'EUW1_6871150879',
#  'EUW1_6870871076',
#  'EUW1_6870843961',
#  'EUW1_6870724136',
#  'EUW1_6870681098',
#  'EUW1_6870649711',
#  'EUW1_6870601630',
#  'EUW1_6870496434',
#  'EUW1_6870462631']

# %%
match_info_url = f"https://europe.api.riotgames.com/lol/match/v5/matches/{recent_games_response.json()[0]}?api_key={API_KEY}"
match_info_url
# Out:
# 'https://europe.api.riotgames.com/lol/match/v5/matches/EUW1_6872214190?api_key=RGAPI-a9076744-a527-485a-907b-0fc75c93071a'

# %%
match_info_response = requests.get(match_info_url)
match_info_response.json()
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'EUW1_6872214190',
#   'participants': ['BSCteY9RPORgd1Mo5m9wsfOMV5iZV6OlCqHx0I76NOJYwa9ZAATxvfItkAX618ziPC4iwbfwTK4CDg',
#    '3nr_4tZu2kCSA0oxbs5RnUzpF-BF-j0SkiQC1A6fgzpg3Rkma5gI5CWo00_sHmMvIpiqlDQnYB5XMw',
#    'R-26K_KELluOBMfWPA4VdxVOTtuaD3-jBIZSWnXjbF2qnmcDtmXrhfBimntWgL0-7BjdGnvShVUAXw',
#    'WAJysN4Y35yR2R_ZYF5m7FW3zLEEVOMq4Eqp7p681jv39anqhYsXcFdU6tK18jCtjElWak-gr8hhew',
#    '74lJ-rrsAZXiiMvA1Q0c8NzlG2RHdsgVEbMTpjrzMcQOz4YB0LgTwwog4BjlAoSu2sqsKuuLTKvjXw',
#    'Gy0w-2PtuRAXY9aG4NggV18LQGemjXQ4FpwiPbraRZU5_yGqRCCA6sJw4HFbQzDnlcgcgzzWr1BAgA',
#    'ES7DDpAwii2zVHB9FmAQK-Jbi195fVFVyulMF9QVxAZrZKvy2xMa32mSZ5GxFcKjHXeSeXJCPj3VuQ',
#    'iEcCMZVAya2OoEUJLjCO5p4-z9rBBATne2gpqvg2p3w2mSVuSNG1YLWSf9k6ACMKC8XgkY-wydwwoA',
#    'oZ-zZb3mdXcNFE0gewUbAqcjEWxWB7K2KxvqaWCEusHjxfaXNyZcA9yJA0iGKmRWS_o_hVA3XTytWg',
#    '5LMwhEO8p9KjJdQ3b6wAjJw42_94zwmlChyJE1dTWa1PGJXoAKgY7K1Pe2DQ1rzm-mR9TT_jFaRv5g']},
# ...

# %%
matchinfo = match_info_response.json()

# %%
import pandas as pd

participants = matchinfo['info']['participants']
df = pd.DataFrame(participants)
df['championName'] = df['championName'].apply(lambda x: x['championName'])
matchinfo['info']['participants'][1]['championName']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 import pandas as pd
#       3 participants = matchinfo['info']['participants']
#       4 df = pd.DataFrame(participants)
#
# ModuleNotFoundError: No module named 'pandas'
