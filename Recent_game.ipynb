# %%
print("Hello!")
# Out:
# Hello!

# %%
#My dev key that I got from the Riot Games API (updates every 24hrs)
API_KEY = "RGAPI-a9076744-a527-485a-907b-0fc75c93071a"

# %%
API_KEY
# Out:
# 'RGAPI-a9076744-a527-485a-907b-0fc75c93071a'

# %%
import requests

# %%
# making a function that takes a playername and returns the url needed in the get request
def convert_playername_to_url(playername):
    base_url = "https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/"
    api_key = "RGAPI-a9076744-a527-485a-907b-0fc75c93071a"
    url = base_url + playername + "?api_key=" + api_key
def convert_playername_to_url(playername):
    base_url = "https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/"
    api_key = API_KEY
    formatted_playername = playername.replace(" ", "%20")
    url = base_url + formatted_playername + "?api_key=" + api_key
    return url

# %%
#essensially the player name is the input of this notebook
playername = "zz TOP KING"

# %%
#getting the url
API_URL = convert_playername_to_url(playername)

# %%
API_URL
# Out:
# 'https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/zz%20TOP%20KING?api_key=RGAPI-a9076744-a527-485a-907b-0fc75c93071a'

# %%
#TEST: URL = "https://euw1.api.riotgames.com/lol/summoner/v4/summoners/by-name/zz%20TOP%20KING"

# %%
#Checking if the URL is correct by getting the 200 status code and not 4** or 5**
requests.get(API_URL )
# Out:
# <Response [200]>

# %%
response = requests.get(API_URL)
response
# Out:
# <Response [200]>

# %%
#opening the response
player_info = response.json()
player_info
# Out:
# {'id': 'hRJRx3MwMm8u2VmVqIoQ2vNODIlV3roAdw0lk1W2e0eYv08',
#  'accountId': 'NsQeArIgCq9vvilVMe3lMMblCQybEsj7TcjFOantyG8hmA',
#  'puuid': '3nr_4tZu2kCSA0oxbs5RnUzpF-BF-j0SkiQC1A6fgzpg3Rkma5gI5CWo00_sHmMvIpiqlDQnYB5XMw',
#  'name': 'zz TOP KING',
#  'profileIconId': 6570,
#  'revisionDate': 1711473911753,
#  'summonerLevel': 396}

# %%
#definig the player account id for later use
player_account_id = player_info['puuid']
player_account_id
# Out:
# '3nr_4tZu2kCSA0oxbs5RnUzpF-BF-j0SkiQC1A6fgzpg3Rkma5gI5CWo00_sHmMvIpiqlDQnYB5XMw'

# %%
#making a url to get the IDs of recent 20 games of the player
recent_games_url = f"https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/{player_account_id}/ids?start=0&count=20" + "&api_key=" + API_KEY

# %%
recent_games_url
# Out:
# 'https://europe.api.riotgames.com/lol/match/v5/matches/by-puuid/3nr_4tZu2kCSA0oxbs5RnUzpF-BF-j0SkiQC1A6fgzpg3Rkma5gI5CWo00_sHmMvIpiqlDQnYB5XMw/ids?start=0&count=20&api_key=RGAPI-a9076744-a527-485a-907b-0fc75c93071a'

# %%
recent_games_response = requests.get(recent_games_url)

# %%
recent_games_response.json()
# Out:
# ['EUW1_6872872176',
#  'EUW1_6872818897',
#  'EUW1_6872781222',
#  'EUW1_6872214190',
#  'EUW1_6872175419',
#  'EUW1_6872168571',
#  'EUW1_6872117584',
#  'EUW1_6872062333',
#  'EUW1_6872007739',
#  'EUW1_6871962398',
#  'EUW1_6871900515',
#  'EUW1_6871812050',
#  'EUW1_6871726206',
#  'EUW1_6871191443',
#  'EUW1_6871150879',
#  'EUW1_6870871076',
#  'EUW1_6870843961',
#  'EUW1_6870724136',
#  'EUW1_6870681098',
#  'EUW1_6870649711']

# %%
#making a url to get the info of the most recent game
match_info_url = f"https://europe.api.riotgames.com/lol/match/v5/matches/{recent_games_response.json()[0]}?api_key={API_KEY}"
match_info_url
# Out:
# 'https://europe.api.riotgames.com/lol/match/v5/matches/EUW1_6872872176?api_key=RGAPI-a9076744-a527-485a-907b-0fc75c93071a'

# %%
#getting the info of the most recent game
match_info_response = requests.get(match_info_url)
match_info_response.json()
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'EUW1_6872872176',
#   'participants': ['3nr_4tZu2kCSA0oxbs5RnUzpF-BF-j0SkiQC1A6fgzpg3Rkma5gI5CWo00_sHmMvIpiqlDQnYB5XMw',
#    '55C68-GYDIj_uDWSDhFkJHSRneuwubZtUG-_ZaKDLns1ylIViXC6mmlqOYCCVXFTbT7y1M5PLWjy6g',
#    'm6ZCXcnThl9nIZDEhCcUXPI-w-kot0YzHMQUzeOue8TXCXjJcG1b8T0pRg-lwWiHH7uJKI28Kr3VXw',
#    'mWDK3HdBP9EWNlHOjrk00BHeSnRdufM30jXSdo9CySawshjxJYyU-CrplorgEB-wki51p6DutR-mMA',
#    'hhr7t2fNMUL1JsGPQ_q5KhvtYvrB8EAWvSVezvSLUaiN98avh6hplTMgoWFVjPChEM_vtONosLh9cg',
#    'eBIaBtkgh8zJUdaC1drj7kWQlhvm2zZpMTKiOroeOZpk5jG-V1xiMCHhoxHyNsH9uPfDAXQDfM2VtQ',
#    'zMitB4S9uePm3N2cVLF1qhkJScxO8aiNYJnde6H8BgKpj75APEV6mubhBArfywwkbi7RGAvYzamO-A',
#    'Jaj96PR0n_JgMY5o6wd_VsNehjGK8Slr_K3j-Fb0qNxfzwkcWNOxmLyScOeA9O1xyhyq4XCmxCLPWA',
#    'dnSErNIOFVgrbYmfNtEd3hQx5e-mDp2uII9pDasSYeMInPBIlx_leYI-w4wJVVk_QMg0Lt55xUWa4Q',
#    '9_NLxSdU-_fHLqE1CpMPVb8vcjs6cKv4twp-fFrlwmMxGExxooP-8o96zzrPftpGnhURWNvMrMLamQ']},
# ...

# %%
matchinfo = match_info_response.json()

# %%
#putting it into a pandas dataframe with basic information
import pandas as pd
df_all = pd.DataFrame(matchinfo['info']['participants'])
df_basic = df_all[['summonerName', 'championName', 'win']]
df_basic
# Out:
#    summonerName championName    win
# 0   zz TOP KING       KSante  False
# 1                       Nunu  False
# 2  Muryò kuusho      Leblanc  False
# 3       0dlanor         Jinx  False
# 4       fab3000         Lulu  False
# 5     GHR Atlas         Gnar   True
# 6    Spinnewipp        Diana   True
# 7       Aranior         Azir   True
# 8   Laulilalinc        Kaisa   True
# 9       Monzo13      Camille   True

# %%
#finding the index of the player that was inputted in the beginning
selected_player_index = matchinfo['metadata']['participants'].index(player_account_id)
selected_player_index
# Out:
# 0

# %%
#showing information about the player that was inputted in the beginning in the most recent game
matchinfo['info']['participants'][selected_player_index]
# Out:
# {'allInPings': 0,
#  'assistMePings': 1,
#  'assists': 2,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 0,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 298,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronTakedowns': 0,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 0,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardsPlaced': 0,
#   'damagePerMinute': 684.0658182642289,
#   'damageTakenOnTeamPercentage': 0.2327221961009389,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 5,
#   'dodgeSkillShotsSmallWindow': 0,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'earlyLaningPhaseGoldExpAdvantage': 0,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 64,
#   'enemyJungleMonsterKills': 0,
#   'epicMonsterKillsNearEnemyJungler': 0,
#   'epicMonsterKillsWithin30SecondsOfSpawn': 0,
# ...
